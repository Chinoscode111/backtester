# %%
# !pip install yfinance
# Out:
# ...
# DEPRECATION: Loading egg at c:\users\dell\appdata\local\programs\python\python311\lib\site-packages\apache_beam-2.54.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\dell\appdata\local\programs\python\python311\lib\site-packages\avro_python3-1.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\dell\appdata\local\programs\python\python311\lib\site-packages\contextlib2-21.6.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...

# %%
import yfinance as yf
import pandas as pd

# %%
def download_historical_data (symbol , start_date , end_date , timeframe = '1D'):
    data = yf.download(symbol , start_date , end_date , timeframe)
    return data

# %%
historical_data = download_historical_data('BTC-USD' , '2020-01-01'  ,'2024-01-01'  , '1D')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
historical_data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-01-01   7194.892090   7254.330566   7174.944336   7200.174316
# 2020-01-02   7202.551270   7212.155273   6935.270020   6985.470215
# 2020-01-03   6984.428711   7413.715332   6914.996094   7344.884277
# 2020-01-04   7345.375488   7427.385742   7309.514160   7410.656738
# 2020-01-05   7410.451660   7544.497070   7400.535645   7411.317383
# ...                  ...           ...           ...           ...
# 2023-12-27  42518.468750  43683.160156  42167.582031  43442.855469
# 2023-12-28  43468.199219  43804.781250  42318.550781  42627.855469
# 2023-12-29  42614.644531  43124.324219  41424.062500  42099.402344
# 2023-12-30  42091.753906  42584.125000  41556.226562  42156.902344
# 2023-12-31  42152.097656  42860.937500  41998.253906  42265.187500
#
#                Adj Close       Volume  Dividends  Stock Splits
# Date
# 2020-01-01   7200.174316  18565664997        0.0           0.0
# ...
